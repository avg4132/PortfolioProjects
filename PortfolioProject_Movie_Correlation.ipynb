# %%
#Import Libraries

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) #Adjusts the configuration of the plots I create

# %%
#Read in the Data
df = pd.read_csv("Movies.csv")

# %%
#Let's look at the Data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#Check for Missing Data and remove NULL Values

for col in df.columns:
    
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
df.dtypes
df = df.dropna()

# %%
#Change Data types of Columns

df['budget'] = df['budget'].astype('int64', errors='ignore')
df['gross'] = df['gross'].astype('int64', errors='ignore')

df.head() #to verify change in data type
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
#Make sure 'Released' and 'Year' are the same, and create new column

df['year_correct'] = df['released'].astype(str).str.rsplit(',').str[-1]
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1127    7.7   221000.0       889    1413
# 4   732       6      4  1980      1170    7.3   108000.0       719     351
#
#    star  country    budget      gross  company  runtime  yearcorrect  \
# 0   699       46  19000000   46998772     1426    146.0         1304
# 1   214       47   4500000   58853106      452    104.0         1127
# 2  1157       47  18000000  538375067      945    124.0         1359
# 3  1474       47   3500000   83453539     1108     88.0         1127
# 4   271       47   6000000   39846344     1083     98.0         1170
#
#   year_correct
# 0         1304
# 1         1127
# 2         1359
# 3         1127
# 4         1170

# %%
#Sort by Gross Revenue
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
pd.set_option('display.max_rows', None)
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1127    7.7   221000.0       889    1413
# 4   732       6      4  1980      1170    7.3   108000.0       719     351
#
#    star  country    budget      gross  company  runtime  yearcorrect  \
# 0   699       46  19000000   46998772     1426    146.0         1304
# 1   214       47   4500000   58853106      452    104.0         1127
# 2  1157       47  18000000  538375067      945    124.0         1359
# 3  1474       47   3500000   83453539     1108     88.0         1127
# 4   271       47   6000000   39846344     1083     98.0         1170
#
#    year_correct
# 0             0
# 1             0
# 2             0
# 3             0
# ...

# %%
#Drop any duplicates
df['name'] = df['name'].drop_duplicates().sort_values(ascending=False)

# %%
#Predict high correlations between High Budgets/Company and Revenue
#Build a scatterplot with budget vs gross 


plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Revenue')
plt.xlabel('Gross Revenue')
plt.ylabel('Budget')
plt.show()

# %%
#Regression plot for Revenue and Budget with seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#Looking at correlations
correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
df_correlations = df
for col_name in df_correlations:
    if (df_correlations[col_name].dtype=='object'):
        df_correlations[col_name] = df_correlations[col_name].astype('category')
        df_correlations[col_name] = df_correlations[col_name].cat.codes
        
df_correlations.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1127    7.7   221000.0       889    1413
# 4   732       6      4  1980      1170    7.3   108000.0       719     351
#
#    star  country    budget      gross  company  runtime  yearcorrect  \
# 0   699       46  19000000   46998772     1426    146.0         1304
# 1   214       47   4500000   58853106      452    104.0         1127
# 2  1157       47  18000000  538375067      945    124.0         1359
# 3  1474       47   3500000   83453539     1108     88.0         1127
# 4   271       47   6000000   39846344     1083     98.0         1170
#
#    year_correct
# 0             0
# 1             0
# 2             0
# 3             0
# ...

# %%
correlation_matrix = df_correlations.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
#Unstack correlations
correlation_matrix = df_correlations.corr()
corr_pairs = correlation_matrix.unstack()
corr_pairs
# Out:
# name          name            1.000000
#               rating         -0.029370
#               genre           0.010585
#               year           -0.000134
#               released       -0.001980
#               score           0.019283
#               votes           0.004792
#               director        0.016063
#               writer          0.019621
#               star           -0.013372
#               country        -0.025229
#               budget          0.007664
#               gross          -0.009956
#               company         0.024068
#               runtime         0.004559
#               yearcorrect    -0.001980
#               year_correct   -0.000426
# rating        name           -0.029370
#               rating          1.000000
#               genre           0.147796
#               year            0.019499
#               released        0.018083
#               score           0.065983
#               votes           0.006031
# ...

# %%
#alternative sorting
sorted_pairs = corr_pairs.sort_values()
sorted_pairs


high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# gross         votes           0.614751
# votes         gross           0.614751
# gross         budget          0.740247
# budget        gross           0.740247
# year_correct  year            0.961218
# year          year_correct    0.961218
# name          name            1.000000
# writer        writer          1.000000
# yearcorrect   released        1.000000
# rating        rating          1.000000
# genre         genre           1.000000
# year          year            1.000000
# released      released        1.000000
#               yearcorrect     1.000000
# score         score           1.000000
# yearcorrect   yearcorrect     1.000000
# votes         votes           1.000000
# star          star            1.000000
# country       country         1.000000
# budget        budget          1.000000
# gross         gross           1.000000
# company       company         1.000000
# runtime       runtime         1.000000
# director      director        1.000000
# ...

# %%
#Budget and Gross have the highest relevant correlation
